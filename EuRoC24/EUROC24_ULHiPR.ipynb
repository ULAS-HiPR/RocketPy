# %% [markdown]
# # Sample Simulation

# %% [markdown]
# ## Setup

# %%
# Install the RocketPy package using pip
# !pip install rocketpy
# Out:
# Requirement already satisfied: rocketpy in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from rocketpy) (1.25.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from rocketpy) (1.11.4)
# Requirement already satisfied: matplotlib>=3.0 in /usr/local/lib/python3.10/dist-packages (from rocketpy) (3.7.1)
# Requirement already satisfied: netCDF4>=1.6.4 in /usr/local/lib/python3.10/dist-packages (from rocketpy) (1.6.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from rocketpy) (2.31.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from rocketpy) (2023.4)
# Requirement already satisfied: simplekml in /usr/local/lib/python3.10/dist-packages (from rocketpy) (1.3.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->rocketpy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->rocketpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->rocketpy) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->rocketpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->rocketpy) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->rocketpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->rocketpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0->rocketpy) (2.8.2)
# Requirement already satisfied: cftime in /usr/local/lib/python3.10/dist-packages (from netCDF4>=1.6.4->rocketpy) (1.6.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from netCDF4>=1.6.4->rocketpy) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->rocketpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->rocketpy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->rocketpy) (2.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0->rocketpy) (1.16.0)
# '\n# Download NACA0012-radians.csv file using curl from RocketPy GitHub repository\n!curl -o NACA0012-radians.csv https://raw.githubusercontent.com/RocketPy-Team/RocketPy/master/data/calisto/NACA0012-radians.csv\n\n# Download Cesaroni_M1670.eng file using curl from RocketPy GitHub repository\n!curl -o Cesaroni_M1670.eng https://raw.githubusercontent.com/RocketPy-Team/RocketPy/master/data/motors/Cesaroni_M1670.eng\n\n# Download powerOffDragCurve.csv file using curl from RocketPy GitHub repository\n!curl -o powerOffDragCurve.csv https://raw.githubusercontent.com/RocketPy-Team/RocketPy/master/data/calisto/powerOffDragCurve.csv\n\n# Download powerOnDragCurve.csv file using curl from RocketPy GitHub repository\n!curl -o powerOnDragCurve.csv https://raw.githubusercontent.com/RocketPy-Team/RocketPy/master/data/calisto/powerOnDragCurve.csv\n'

# %%
from rocketpy import Environment, SolidMotor, Rocket, Flight

# %%
# Used for tidying up the outputted data - not critical for operations

# Configure the InlineBackend to display SVG figures
# %config InlineBackend.figure_formats = ['svg']

# Ensure that matplotlib plots are displayed inline in the Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ## Setting Up a Simulation

# %% [markdown]
# ### Creating an Environment

# %%
# Current location based on EUROC 2022 Launch Operations Guide (https://euroc.pt/wp-content/uploads/2022/09/PTS_EDU_EuRoC_ST_000763_LOG_v01.pdf Section 2.3) + elevation calculator website 
env = Environment(latitude=39.4310, longitude=-8.3012, elevation=143)

# %%
import datetime

# Get the date of tomorrow
# Can be any day, just change the 'days' variable equal to the unmber of days between today and the day you want
tomorrow = datetime.date.today() + datetime.timedelta(days=1)

# Set the date and time in the Environment object, with the hour given in UTC time
env.set_date((tomorrow.year, tomorrow.month, tomorrow.day, 12))

# %%
# Set the atmospheric model type to "Forecast" and specify the file for the Global Forecast System (GFS)
env.set_atmospheric_model(type="Forecast", file="GFS")

# %%
# Retrieve all information about the Environment object
env.all_info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.8008 m/s²
# Acceleration of gravity at  79.320 km (ASL): 9.5610 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2024-07-31 12:00:00 UTC
# Launch Site Latitude: 39.43100°
# Launch Site Longitude: -8.30120°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 43631.08 W    4378037.58 N
# Launch Site UTM zone: 30S
# Launch Site Surface Elevation: 140.8 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: Forecast
# Forecast Maximum Height: 79.320 km
# Forecast Time Period: From  2024-07-30 06:00:00  to  2024-08-15 06:00:00  UTC
# Forecast Hour Interval: 3  hrs
# Forecast Latitude Range: From  -90.0 ° To  90.0 °
# Forecast Longitude Range: From  0.0 ° To  359.75 °
#
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 3.41 m/s
# Surface Wind Direction: 304.20°
# Surface Wind Heading: 124.20°
# Surface Pressure: 998.76 hPa
# Surface Temperature: 303.92 K
# Surface Air Density: 1.145 kg/m³
# Surface Speed of Sound: 349.48 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6369.55 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
#
# Gravity Model Plots
# Atmospheric Model Plots

# %% [markdown]
# ### Creating a Motor

# %%
PRO75L645 = SolidMotor(
    
    thrust_source="..\EuRoC24\Sim-Files\Motors\Cesaroni_3419L645-P.eng", # .eng file containing thrust data

    dry_mass=1.6077, # Dry mass of the motor in kilograms
    # Assumption - Sean Reynolds Number
    dry_inertia=(0.039, 0.039, 0.0015), # Dry mass moments of inertia in kg*m^2
    # Assumption
    nozzle_radius = 37.5 / 1000, # Radius of the nozzle exit in meters
    # Correct
    grain_number=3, # Number of propellant grains
    # Assumption - Sean Bourke
    grain_density=1815, # Density of the propellant in kg/m^3
    # Assumption
    grain_outer_radius = 37.5 / 1000, # Outer radius of the propellant grains in meters (37.5)
    # Assumption
    grain_initial_inner_radius=29 / 1000, # Initial inner radius of the propellant grains in meters
    # Assumption - prolly important
    grain_initial_height=157 / 1000, # Initial height of the propellant grains in meters
    # Assumption - prolly important
    grain_separation=5 / 1000, # Separation between propellant grains in meters
    #Assumption - prolly important
    grains_center_of_mass_position=0.343, # Position of the center of mass of the propellant grains
    # Assumption
    center_of_dry_mass_position=0.231, # Position of the center of mass of the dry motor
    # Correct
    nozzle_position = 0.0, # Position of the nozzle relative to the combustion chamber
    # Correct
    burn_time=5.3, # Burn time of the motor in seconds

    throat_radius=12.5 / 1000, # Radius of the motor throat in meters
    # Known
    coordinate_system_orientation="nozzle_to_combustion_chamber" # Orientation of the coordinate system -> EXTREMLY IMPORTANT
)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\E'
# <>:3: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\assas\AppData\Local\Temp\ipykernel_40484\1076534736.py:3: SyntaxWarning: invalid escape sequence '\E'
#   thrust_source="..\EuRoC24\Sim-Files\Motors\Cesaroni_3419L645-P.eng", # .eng file containing thrust data

# %%
# Retrieve all information about the SolidMotor object
PRO75L645.all_info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.0375 m
# Nozzle Throat Radius: 0.0125 m
#
# Grain Details
# Number of Grains: 3
# Grain Spacing: 0.005 m
# Grain Density: 1815 kg/m3
# Grain Outer Radius: 0.0375 m
# Grain Inner Radius: 0.029 m
# Grain Height: 0.157 m
# Grain Volume: 0.000 m3
# Grain Mass: 0.506 kg
#
# Motor Details
# Total Burning Time: 5.3 s
# Total Propellant Mass: 1.518 kg
# Average Propellant Exhaust Velocity: 2260.216 m/s
# Average Thrust: 647.384 N
# Maximum Thrust: 764.97 N at 2.043 s after ignition.
# Total Impulse: 3431.136 Ns

# %% [markdown]
# ### Creating a Rocket

# %%
# Define a Rocket object with specific parameters
rocket = Rocket(
    radius=102 / 1000, # Radius of the rocket body in meters
    mass=5.505, # Total mass of the rocket in kilograms
    # These need to be checked
    inertia=(1.62 , 1.62, 0.012), # Moments of inertia of the rocket in kg*m^2

    power_off_drag = "..\EuRoC24\Sim-files\Aero\CD-Power-Off.csv", # .csv file containing power-off drag curve data

    power_on_drag = "..\EuRoC24\Sim-files\Aero\CD-Power-On.csv", # .csv file containing power-on drag curve data

    center_of_mass_without_motor=(191-98.7)/100, # Position of the center of mass of the rocket without the motor

    coordinate_system_orientation="tail_to_nose" # Orientation of the coordinate system -> EXTREMLY IMPORTANT -> MUST be relative to the coordinate system defined in the motor
)

# Set the rail buttons for the rocket
rail_buttons = rocket.set_rail_buttons(
    upper_button_position=0.504, # Position of the upper rail button relative to the ROCKET NOZZLE
    lower_button_position=0.256, # Position of the lower rail button relative to the ROCKET NOZZLE
    angular_position=180, # Angular position of the rail buttons in degrees
)
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\E'
# <>:10: SyntaxWarning: invalid escape sequence '\E'
# <>:8: SyntaxWarning: invalid escape sequence '\E'
# <>:10: SyntaxWarning: invalid escape sequence '\E'
# C:\Users\assas\AppData\Local\Temp\ipykernel_40484\3892123886.py:8: SyntaxWarning: invalid escape sequence '\E'
#   power_off_drag = "..\EuRoC24\Sim-files\Aero\CD-Power-Off.csv", # .csv file containing power-off drag curve data
# C:\Users\assas\AppData\Local\Temp\ipykernel_40484\3892123886.py:10: SyntaxWarning: invalid escape sequence '\E'
#   power_on_drag = "..\EuRoC24\Sim-files\Aero\CD-Power-On.csv", # .csv file containing power-on drag curve data

# %%
# Add the motor object to the rocket object at a specific position
# Said position is EXTREMLY IMPORTANT
rocket.add_motor(PRO75L645, position=0)

# %% [markdown]
# ### Adding Aerodynamic Surfaces

# %%
# Add a nose cone to the rocket object with specific parameters
nose_cone = rocket.add_nose(length=0.41, kind="lvhaack", position=1.91)

# Add trapezoidal fins to the rocket with specific parameters
fin_set = rocket.add_trapezoidal_fins(
    n=3, # Number of fins
    root_chord=0.204, # Root chord length of the fins in meters
    tip_chord=0.102, # Tip chord length of the fins in meters
    span=0.141, # Span of the fins in meters
    position=0.32, # Position of the fins relative to the rocket nose
    cant_angle=0, # Cant angle of the fins in radians
    ##airfoil=("clvalpha.csv", "degrees"), # Airfoil profile of the fins -> .csv file and declare your unit of measurment (radians OR degrees)
)

# Add a tail to the rocket object with specific parameters
tail = rocket.add_tail(
    top_radius = 102 / 1000, # Top radius of the tail in meters
    bottom_radius=0.07, # Bottom radius of the tail in meters
    length=0.1, # Length of the tail in meters
    position=0.1 # Position of the tail relative to the rocket nose
)

# %%
# Retrieve all information about the Rocket object
rocket.all_info()
# Out:
# Inertia Details
#
# Rocket Mass: 5.505 kg (without motor)
# Rocket Dry Mass: 7.113 kg (with unloaded motor)
# Rocket Loaded Mass: 8.631 kg (with loaded motor)
# Rocket Inertia (with unloaded motor) 11: 2.255 kg*m2
# Rocket Inertia (with unloaded motor) 22: 2.255 kg*m2
# Rocket Inertia (with unloaded motor) 33: 0.013 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.102 m
# Rocket Frontal Area: 0.032685 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.156 m
# Rocket Center of Dry Mass - Nozzle Exit: 0.767 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.424 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.075 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 3.391/rad
# Tail Lift Coefficient Derivative: -1.058/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: 1.679 m
# Fins Center of Pressure position: 0.235 m
# Tail Center of Pressure position: 0.053 m
#
# Stability
#
# Center of Mass position (time=0): 0.692 m
# Center of Pressure position (time=0): 0.946 m
# Initial Static Margin (mach=0, time=0): -1.245 c
# Final Static Margin (mach=0, time=burn_out): -0.880 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.254 m
#
#
# Rocket Draw
# ----------------------------------------
# Mass Plots
# ----------------------------------------
# Aerodynamics Plots
# ----------------------------------------
# Drag Plots
# --------------------
# Stability Plots
# --------------------
# Thrust-to-Weight Plot
# ----------------------------------------

# %% [markdown]
# ### Adding Parachutes

# %%
# Add a main parachute to the rocket with specific parameters
Main = rocket.add_parachute(
    "Main", # Name of the parachute
    cd_s = 1.0, # Drag coefficient of the parachute in m^2
    trigger = 200, # Trigger for parachute deployment can be EITHER an altitude in meters OR an event
    sampling_rate = 105, # Sampling rate for parachute simulation
    lag = 1.5, # Lag time for parachute deployment in seconds
    noise = (0, 8.3, 0.5), # Noise parameters for parachute simulation
)

# Add a drogue parachute to the rocket with specific parameters
Drogue = rocket.add_parachute(
    "Drogue", # Name of the parachute
    cd_s = 0.2, # Drag coefficient of the parachute in m^2
    trigger = "apogee", # Trigger for parachute deployment can be EITHER an altitude in meters OR an event
    sampling_rate = 105, # Sampling rate for parachute simulation
    lag = 1.5, # Lag time for parachute deployment in seconds
    noise = (0, 8.3, 0.5), # Noise parameters for parachute simulation
)

# %% [markdown]
# ## Simulating a Flight

# %%
# Create a Flight object named test_flight with specific parameters
test_flight = Flight(
    rocket=rocket, # Rocket object representing the rocket to be simulated
    environment=env, # Environment object representing the atmospheric and environmental conditions
    rail_length=12, # Length of the launch rail in meters
    inclination=84, # Inclination angle of the launch rail in degrees
    heading = 170 # Heading angle of the launch rail in degrees
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Create a Flight object named test_flight with specific parameters
# ----> 2 test_flight = Flight(
#       3     rocket=rocket, # Rocket object representing the rocket to be simulated
#       4     environment=env, # Environment object representing the atmospheric and environmental conditions
#       5     rail_length=12, # Length of the launch rail in meters
#       6     inclination=84, # Inclination angle of the launch rail in degrees
#       7     heading = 170 # Heading angle of the launch rail in degrees
#       8 )
#
# File c:\Users\assas\OneDrive - University of Limerick\AeroSoc\Simulations\HiPR Sims\RocketPy\.conda\Lib\site-packages\rocketpy\simulation\flight.py:622, in Flight.__init__(self, rocket, environment, rail_length, inclination, heading, initial_solution, terminate_on_apogee, max_time, max_time_step, min_time_step, rtol, atol, time_overshoot, verbose, name, equations_of_motion)
#     619 self.flight_phases.add_phase(self.max_time)
#     621 # Simulate flight
# --> 622 self.__simulate(verbose)
#     624 # Initialize prints and plots objects
#     625 self.prints = _FlightPrints(self)
#
# File c:\Users\assas\OneDrive - University of Limerick\AeroSoc\Simulations\HiPR Sims\RocketPy\.conda\Lib\site-packages\rocketpy\simulation\flight.py:751, in Flight.__simulate(self, verbose)
#     748 # Step through simulation
#     749 while phase.solver.status == "running":
#     750     # Execute solver step, log solution and function evaluations
# --> 751     phase.solver.step()
#     752     self.solution += [[phase.solver.t, *phase.solver.y]]
#     753     self.function_evaluations.append(phase.solver.nfev)
#
# File c:\Users\assas\OneDrive - University of Limerick\AeroSoc\Simulations\HiPR Sims\RocketPy\.conda\Lib\site-packages\scipy\integrate\_ivp\base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File c:\Users\assas\OneDrive - University of Limerick\AeroSoc\Simulations\HiPR Sims\RocketPy\.conda\Lib\site-packages\scipy\integrate\_ivp\lsoda.py:161, in LSODA._step_impl(self)
#     159 itask = integrator.call_args[2]
#     160 integrator.call_args[2] = 5
# --> 161 solver._y, solver.t = integrator.run(
#     162     solver.f, solver.jac or (lambda: None), solver._y, solver.t,
#     163     self.t_bound, solver.f_params, solver.jac_params)
#     164 integrator.call_args[2] = itask
#     166 if solver.successful():
#
# File c:\Users\assas\OneDrive - University of Limerick\AeroSoc\Simulations\HiPR Sims\RocketPy\.conda\Lib\site-packages\scipy\integrate\_ode.py:1347, in lsoda.run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1344     self.acquire_new_handle()
#    1345 args = [f, y0, t0, t1] + self.call_args[:-1] + \
#    1346        [jac, self.call_args[-1], f_params, 0, jac_params]
# -> 1347 y1, t, istate = self.runner(*args)
#    1348 self.istate = istate
#    1349 if istate < 0:
#
# File c:\Users\assas\OneDrive - University of Limerick\AeroSoc\Simulations\HiPR Sims\RocketPy\.conda\Lib\site-packages\scipy\integrate\_ivp\base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File c:\Users\assas\OneDrive - University of Limerick\AeroSoc\Simulations\HiPR Sims\RocketPy\.conda\Lib\site-packages\scipy\integrate\_ivp\base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# File c:\Users\assas\OneDrive - University of Limerick\AeroSoc\Simulations\HiPR Sims\RocketPy\.conda\Lib\site-packages\rocketpy\simulation\flight.py:1633, in Flight.u_dot_generalized(self, t, u, post_processing)
#    1631 wind_velocity = Vector([wind_velocity_x, wind_velocity_y, 0])
#    1632 free_stream_speed = abs((wind_velocity - Vector(v)))
# -> 1633 speed_of_sound = self.env.speed_of_sound.get_value_opt(z)
#    1634 free_stream_mach = free_stream_speed / speed_of_sound
#    1636 if t < self.rocket.motor.burn_out_time:
#
# File c:\Users\assas\OneDrive - University of Limerick\AeroSoc\Simulations\HiPR Sims\RocketPy\.conda\Lib\site-packages\rocketpy\mathutils\function.py:481, in Function.__get_value_opt_1d(self, x)
#     479 coeffs = self._coeffs
#     480 if x_min <= x <= x_max:
# --> 481     y = self._interpolation_func(x, x_min, x_max, x_data, y_data, coeffs)
#     482 else:
#     483     y = self._extrapolation_func(x, x_min, x_max, x_data, y_data, coeffs)
#
# File c:\Users\assas\OneDrive - University of Limerick\AeroSoc\Simulations\HiPR Sims\RocketPy\.conda\Lib\site-packages\rocketpy\mathutils\function.py:353, in Function.__set_interpolation_func.<locals>.linear_interpolation(x, x_min, x_max, x_data, y_data, coeffs)
#     351 y_left = y_data[x_interval - 1]
#     352 dx = float(x_data[x_interval] - x_left)
# --> 353 dy = float(y_data[x_interval] - y_left)
#     354 return (x - x_left) * (dy / dx) + y_left
#
# KeyboardInterrupt:

# %% [markdown]
# ## Analyzing the Results

# %%
# Retrieve all information about the test_flight Flight object
test_flight.all_info()
# Out:
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 140.84 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.086 | e1: -0.015 | e2: 0.173 | e3: -0.981
# Euler Angles - Spin φ : 0.00° | Nutation θ: -20.00° | Precession ψ: -170.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: -1.245 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: 2.38 m/s
# Lateral Surface Wind Speed: 2.44 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 4 m
# Launch Rail Inclination: 70.00°
# Launch Rail Heading: 170.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.363 s
# Rail Departure Velocity: 22.017 m/s
# Rail Departure Stability Margin: -1.229 c
# Rail Departure Angle of Attack: 8.930°
# Rail Departure Thrust-Weight Ratio: 8.199
# Rail Departure Reynolds Number: 2.688e+05
#
#
# Burn out State
#
# Burn out time: 5.300 s
# Altitude at burn out: 140.841 m (ASL) | -0.000 m (AGL)
# Rocket speed at burn out: 0.000 m/s
# Freestream velocity at burn out: 49.528 m/s
# Mach Number at burn out: 0.000
# Kinetic energy at burn out: 0.000e+00 J
#
#
# Apogee State
#
# Apogee Time: 2.265 s
# Apogee Altitude: 231.182 m (ASL) | 90.341 m (AGL)
# Apogee Freestream Speed: 3.063 m/s
# Apogee X position: 31.453 m
# Apogee Y position: -44.319 m
# Apogee latitude: 39.4306013°
# Apogee longitude: -8.3008337°
#
#
# Parachute Events
#
# Parachute: Main
# 	Ejection time: 2.267 s
# 	Inflation time: 3.767 s
# 	Freestream speed at inflation: 52.435 m/s
# 	Altitude at inflation: 153.102 m (ASL) | 90.341 m (AGL)
# Parachute: Drogue
# 	Ejection time: 2.267 s
# 	Inflation time: 3.767 s
# 	Freestream speed at inflation: 52.435 m/s
# 	Altitude at inflation: 153.102 m (ASL) | 90.341 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 4.051 s
# X impact: 35.832 m
# Y impact: -9.451 m
# Altitude impact: 140.841 m (ASL) | -0.000 m (AGL)
# Latitude: 39.4309150°
# Longitude: -8.3007827°
# Vertical velocity at impact: -41.981 m/s
# Number of parachutes triggered until impact: 2
#
#
# Stability Margin
#
# Initial Stability Margin: -1.245 c at 0.00 s
# Out of Rail Stability Margin: -1.229 c at 0.36 s
# Maximum Stability Margin: -0.975 c at 4.05 s
# Minimum Stability Margin: -1.245 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 93.278 m/s at 3.36 s
# Maximum Mach Number: 0.269 Mach at 3.34 s
# Maximum Reynolds Number: 1.176e+06 at 3.34 s
# Maximum Dynamic Pressure: 5.043e+03 Pa at 3.34 s
# Maximum Acceleration During Motor Burn: 257.106 m/s² at 3.59 s
# Maximum Gs During Motor Burn: 26.217 g at 3.59 s
# Maximum Acceleration After Motor Burn: 0.000 m/s² at 0.00 s
# Maximum Gs After Motor Burn: 0.000 Gs at 0.00 s
# Maximum Stability Margin: -0.975 c at 4.05 s
# Maximum Upper Rail Button Normal Force: 4.233 N
# Maximum Upper Rail Button Shear Force: 3.875 N
# Maximum Lower Rail Button Normal Force: 0.062 N
# Maximum Lower Rail Button Shear Force: 0.056 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 483
# Number of Derivative Functions Evaluation: 15
# Average Function Evaluations per Time Step: 0.031
#
#
#
# Trajectory 3d Plot
# Trajectory Kinematic Plots
# Angular Position Plots
# Path, Attitude and Lateral Attitude Angle plots
# Trajectory Angular Velocity and Acceleration Plots
# Aerodynamic Forces Plots
# Rail Buttons Forces Plots
# Trajectory Energy Plots
# Trajectory Fluid Mechanics Plots
# Trajectory Stability and Control Plots
# Rocket and Parachute Pressure Plots
# Parachute:  Main
# Parachute:  Drogue

# %%
from google.colab import files

# Export the trajectory of the test_flight to a KML file
test_flight.export_kml(
    file_name="Trajectory.kml", # Specify the file name
    extrude=True, # Enable extrusion for 3D visualization
    altitude_mode="relative_to_ground", # Specify the altitude mode
)

# Download the KML file for use in Google Earth
files.download('Trajectory.kml')
# Out:
# File  Trajectory.kml  saved with success!
