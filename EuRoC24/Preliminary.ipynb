# %% [markdown]
# # Preliminary
#
# Preliminary simulation for EuRoC 2024 Concept Report

# %%
import datetime
import matplotlib.pyplot as plt
from rocketpy import Environment, SolidMotor, Rocket, Flight

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ## Setup

# %% [markdown]
# ### 1 - Environment
#
# Assuming:
#
# - Launching 1/2 the runway south across from the paddock
# - Launch day is tomorrow (blocked by: forecast)
# - Launch elevation is what is listed [here](https://www.google.com/maps/place/km+440,37,+Agua+Todo+o+Ano,+Tramaga,+N2,+Ponte+de+Sor,+Portugal/@39.2078514,-8.0619467,16z/data=!4m6!3m5!1s0xd1839fd579834f7:0xe8dd5943368adb9!8m2!3d39.2084353!4d-8.0567479!16s%2Fg%2F11bvtfqbw5?entry=ttu)

# %%
env = Environment(
    latitude=39.207032,
    longitude=-8.058066,
    elevation=440.37,
    date=(datetime.datetime.utcnow() + datetime.timedelta(hours=1)),
)

#
env.set_atmospheric_model(
    type="Forecast",
    file="GFS",
)

env.all_info()
# Out:
# /var/folders/cb/hdthz_ds5kxcy3kxrqpvgbl80000gn/T/ipykernel_84032/2284242297.py:5: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   date=(datetime.datetime.utcnow() + datetime.timedelta(hours=1)),
# Gravity Details
#
# Acceleration of gravity at surface level:    9.8005 m/s²
# Acceleration of gravity at  80.096 km (ASL): 9.5587 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2024-08-08 00:59:44 UTC
# Launch Site Latitude: 39.20703°
# Launch Site Longitude: -8.05807°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 63177.68 W    4351957.33 N
# Launch Site UTM zone: 30S
# Launch Site Surface Elevation: 164.9 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: Forecast
# Forecast Maximum Height: 80.096 km
# Forecast Time Period: From  2024-08-07 18:00:00  to  2024-08-23 18:00:00  UTC
# Forecast Hour Interval: 3  hrs
# Forecast Latitude Range: From  -90.0 ° To  90.0 °
# Forecast Longitude Range: From  0.0 ° To  359.75 °
#
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 4.35 m/s
# Surface Wind Direction: 308.71°
# Surface Wind Heading: 128.71°
# Surface Pressure: 993.89 hPa
# Surface Temperature: 290.70 K
# Surface Air Density: 1.191 kg/m³
# Surface Speed of Sound: 341.80 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6369.64 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
#
# Gravity Model Plots
# Atmospheric Model Plots

# %% [markdown]
# ### 2 - Motor

# %%
PRO75L645 = SolidMotor(
    thrust_source="assets/motors/Cesaroni_3419L645-P.eng",
    dry_mass=1.607,  # kilograms
    dry_inertia=(0.039, 0.039, 0.0015),  # kg*m^2
    nozzle_radius=37.5 / 1000,  # of nozzle exit in meters
    grain_number=3,  # Number of propellant grains
    grain_density=1815,  # kg/m^3
    grain_outer_radius=37.5 / 1000,  # meters
    grain_initial_inner_radius=29 / 1000,  # meters
    grain_initial_height=157 / 1000,  # meters
    grain_separation=5 / 1000,  # meters
    grains_center_of_mass_position=0.343,
    center_of_dry_mass_position=0.231,
    nozzle_position=0.0,  # relative to the combustion chamber
    burn_time=5.3,  # seconds
    throat_radius=12.5 / 1000,  # meters
    coordinate_system_orientation="nozzle_to_combustion_chamber",  # Orientation of the coordinate system -> EXTREMLY IMPORTANT
)
PRO75L645.all_info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.0375 m
# Nozzle Throat Radius: 0.0125 m
#
# Grain Details
# Number of Grains: 3
# Grain Spacing: 0.005 m
# Grain Density: 1815 kg/m3
# Grain Outer Radius: 0.0375 m
# Grain Inner Radius: 0.029 m
# Grain Height: 0.157 m
# Grain Volume: 0.000 m3
# Grain Mass: 0.506 kg
#
# Motor Details
# Total Burning Time: 5.3 s
# Total Propellant Mass: 1.518 kg
# Average Propellant Exhaust Velocity: 2260.216 m/s
# Average Thrust: 647.384 N
# Maximum Thrust: 764.97 N at 2.043 s after ignition.
# Total Impulse: 3431.136 Ns

# %% [markdown]
# ### 3 - Rocket

# %%
rocket = Rocket(
    radius=0.051,  # (r) body in meters 5.1cm = 0.051m
    mass=5.505,  # kg (dry)
    inertia=(1.26, 1.44, 0.3),  # Moments of inertia of the rocket in kg*m^2
    power_off_drag="assets/aero/cd_power_off.csv",  # power-off drag curve csv
    power_on_drag="assets/aero/cd_power_on.csv",  # power-on drag curve csv
    center_of_mass_without_motor=87.1 / 100,
    coordinate_system_orientation="tail_to_nose",  # MUST be relative to the coordinate system defined in the motor
)

rail_buttons = rocket.set_rail_buttons(
    upper_button_position=0.504,  # relative to the rocket nozzle
    lower_button_position=0.256,  # relative to the rocket nozzle
    angular_position=180,  # degrees
)

rocket.add_motor(PRO75L645, position=0)

# %% [markdown]
# ### 4 - Aero surfaces

# %%
nose_cone = rocket.add_nose(
    length=0.410, kind="vonKarman", position=1.92
)  # length in meters, relative to nozzle

# %%
fin_set = rocket.add_trapezoidal_fins(
    n=3,
    root_chord=0.204,  # meters
    tip_chord=0.102,  # meters
    span=0.141,  # meters
    position=0.335,  # relative to the rocket nose
    cant_angle=0,  # radians
    airfoil=("assets/aero/clv_alpha.csv", "degrees"),
)

# %%
tail = rocket.add_tail(
    top_radius=0.051,  # meters
    bottom_radius=37.5 / 1000,  # meters
    length=0.1,  # meters
    position=0.1,  # relative to the rocket nose 181
)

# %% [markdown]
# ### 5 - Recovery

# %%
main_para = rocket.add_parachute(
    "Main",  # name
    cd_s=1.0,  # Drag coefficient of the parachute in m^2
    trigger=800,  # altitude in meters OR an event
    sampling_rate=105,
    lag=1.5,  # seconds
    noise=(0, 8.3, 0.5),
)

drogue_para = rocket.add_parachute(
    "Drogue",  # name
    cd_s=0.313,  # Drag coefficient of the parachute in m^2
    trigger="apogee",  # altitude in meters OR an event
    sampling_rate=105,
    lag=1.5,  # seconds
    noise=(0, 8.3, 0.5),
)

# %%
rocket.all_info()
# Out:
# Inertia Details
#
# Rocket Mass: 5.505 kg (without motor)
# Rocket Dry Mass: 7.112 kg (with unloaded motor)
# Rocket Loaded Mass: 8.630 kg (with loaded motor)
# Rocket Inertia (with unloaded motor) 11: 1.808 kg*m2
# Rocket Inertia (with unloaded motor) 22: 1.988 kg*m2
# Rocket Inertia (with unloaded motor) 33: 0.301 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.051 m
# Rocket Frontal Area: 0.008171 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.145 m
# Rocket Center of Dry Mass - Nozzle Exit: 0.726 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.383 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.067 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 12.152/rad
# Tail Lift Coefficient Derivative: -0.919/rad
#
# Center of Pressure
#
# Nose Cone Center of Pressure position: 1.715 m
# Fins Center of Pressure position: 0.250 m
# Tail Center of Pressure position: 0.053 m
#
# Stability
#
# Center of Mass position (time=0): 0.659 m
# Center of Pressure position (time=0): 0.485 m
# Initial Static Margin (mach=0, time=0): 1.704 c
# Final Static Margin (mach=0, time=burn_out): 2.365 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.174 m
#
#
# Parachute Details
#
# Parachute Main with a cd_s of 1.0000 m2
# Ejection signal trigger: 800 m (AGL)
# Ejection system refresh rate: 105.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 1.5 s
#
#
# Parachute Details
#
# Parachute Drogue with a cd_s of 0.3130 m2
# Ejection signal trigger: At Apogee
# Ejection system refresh rate: 105.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 1.5 s
#
#
# Rocket Draw
# ----------------------------------------
# Mass Plots
# ----------------------------------------
# Aerodynamics Plots
# ----------------------------------------
# Drag Plots
# --------------------
# Stability Plots
# --------------------
# Thrust-to-Weight Plot
# ----------------------------------------

# %% [markdown]
# ## Flight
#
# Flight Trajectory
#
# - Yellow Line: Altitude (height over time)
# - Red Line: Vertical Velocity (speed in the vertical direction)
# - Purple Line: Acceleration (rate of change of velocity)
# - Teal/Cyan Line: Drag Force (aerodynamic drag acting on the rocket)

# %%
flight = Flight(
    rocket=rocket,
    environment=env,
    rail_length=2,  # meters
    inclination=90,  # launch rail (in degrees)
    heading=0,  # launch rail (in degrees)
)
flight.all_info()
# Out:
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 164.93 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 1.000 | e1: 0.000 | e2: 0.000 | e3: 0.000
# Euler Angles - Spin φ : 180.00° | Nutation θ: 0.00° | Precession ψ: -180.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 1.704 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: -2.97 m/s
# Lateral Surface Wind Speed: -3.09 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 2 m
# Launch Rail Inclination: 90.00°
# Launch Rail Heading: 0.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.254 s
# Rail Departure Velocity: 14.129 m/s
# Rail Departure Stability Margin: 1.726 c
# Rail Departure Angle of Attack: 17.020°
# Rail Departure Thrust-Weight Ratio: 8.195
# Rail Departure Reynolds Number: 9.961e+04
#
#
# Burn out State
#
# Burn out time: 5.300 s
# Altitude at burn out: 1114.614 m (ASL) | 949.688 m (AGL)
# Rocket speed at burn out: 312.672 m/s
# Freestream velocity at burn out: 313.068 m/s
# Mach Number at burn out: 0.904
# Kinetic energy at burn out: 3.476e+05 J
#
#
# Apogee State
#
# Apogee Time: 25.193 s
# Apogee Altitude: 3480.570 m (ASL) | 3315.644 m (AGL)
# Apogee Freestream Speed: 27.252 m/s
# Apogee X position: -547.065 m
# Apogee Y position: 680.796 m
# Apogee latitude: 39.2131557°
# Apogee longitude: -8.0644172°
#
#
# Parachute Events
#
# Parachute: Drogue
# 	Ejection time: 25.200 s
# 	Inflation time: 26.700 s
# 	Freestream speed at inflation: 30.696 m/s
# 	Altitude at inflation: 3469.541 m (ASL) | 3315.644 m (AGL)
# Parachute: Main
# 	Ejection time: 143.543 s
# 	Inflation time: 145.043 s
# 	Freestream speed at inflation: 20.604 m/s
# 	Altitude at inflation: 933.958 m (ASL) | 799.893 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 212.676 s
# X impact: -230.829 m
# Y impact: 987.163 m
# Altitude impact: 164.926 m (ASL) | 0.000 m (AGL)
# Latitude: 39.2159116°
# Longitude: -8.0607459°
# Vertical velocity at impact: -10.805 m/s
# Number of parachutes triggered until impact: 2
#
#
# Stability Margin
#
# Initial Stability Margin: 1.704 c at 0.00 s
# Out of Rail Stability Margin: 1.726 c at 0.25 s
# Maximum Stability Margin: 2.365 c at 212.68 s
# Minimum Stability Margin: 1.197 c at 4.00 s
#
#
# Maximum Values
#
# Maximum Speed: 316.737 m/s at 5.08 s
# Maximum Mach Number: 0.915 Mach at 5.08 s
# Maximum Reynolds Number: 1.843e+06 at 5.01 s
# Maximum Dynamic Pressure: 5.272e+04 Pa at 5.04 s
# Maximum Acceleration During Motor Burn: 79.647 m/s² at 2.04 s
# Maximum Gs During Motor Burn: 8.122 g at 2.04 s
# Maximum Acceleration After Motor Burn: 0.000 m/s² at 0.00 s
# Maximum Gs After Motor Burn: 0.000 Gs at 0.00 s
# Maximum Stability Margin: 2.365 c at 212.68 s
# Maximum Upper Rail Button Normal Force: 1.280 N
# Maximum Upper Rail Button Shear Force: 1.241 N
# Maximum Lower Rail Button Normal Force: 1.720 N
# Maximum Lower Rail Button Shear Force: 1.655 N
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 959
# Number of Derivative Functions Evaluation: 169
# Average Function Evaluations per Time Step: 0.176
#
#
#
# Trajectory 3d Plot
# Trajectory Kinematic Plots
# Angular Position Plots
# Path, Attitude and Lateral Attitude Angle plots
# Trajectory Angular Velocity and Acceleration Plots
# Aerodynamic Forces Plots
# Rail Buttons Forces Plots
# Trajectory Energy Plots
# Trajectory Fluid Mechanics Plots
# Trajectory Stability and Control Plots
# Rocket and Parachute Pressure Plots
# Parachute:  Main
# Parachute:  Drogue

# %% [markdown]
# ## Export

# %%
flight.export_kml("assets/results/Preliminary.kml")
# Out:
# File  assets/results/Preliminary.kml  saved with success!
