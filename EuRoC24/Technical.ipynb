# %% [markdown]
# # Technical Review Simulation
#
# Simulation for the EuRoC 2024 Technical Report.
#
# **Team 23**: University of Limerick
#
# **Rocket Airmedh**

# %%
import datetime
from rocketpy import Environment, SolidMotor, Rocket, Flight

# %% [markdown]
# Using latest Python version 3.12 LTS and RocketPy 1.4.0

# %% [markdown]
# ## Environment
#
# Assuming:
#
# - Launching 1/2 the runway south across from the paddock
# - Launch day is tomorrow (blocked by: forecast)
# - Launch elevation is what is listed [here](https://www.google.com/maps/place/km+440,37,+Agua+Todo+o+Ano,+Tramaga,+N2,+Ponte+de+Sor,+Portugal/@39.2078514,-8.0619467,16z/data=!4m6!3m5!1s0xd1839fd579834f7:0xe8dd5943368adb9!8m2!3d39.2084353!4d-8.0567479!16s%2Fg%2F11bvtfqbw5?entry=ttu)

# %%
env = Environment(
    latitude=39.207032,
    longitude=-8.058066,
    elevation=440.37,
)
tomorrow = datetime.date.today() + datetime.timedelta(days=1)
env.set_date((tomorrow.year, tomorrow.month, tomorrow.day, 12))
 

env.set_atmospheric_model(type="Forecast", file="GFS")
env.all_info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.8005 m/s²
# Acceleration of gravity at  79.632 km (ASL): 9.5598 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2026-04-09 12:00:00 UTC
# Launch Site Latitude: 39.20703°
# Launch Site Longitude: -8.05807°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 63177.68 W    4351957.33 N
# Launch Site UTM zone: 30S
# Launch Site Surface Elevation: 164.9 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: Forecast
# Forecast Maximum Height: 79.632 km
# Forecast Time Period: from 2026-04-01 00:00:00 to 2026-04-24 12:00:00 utc
# Forecast Hour Interval: 3 hrs
# Forecast Latitude Range: From 90.0° to -90.0°
# Forecast Longitude Range: From 0.0° to 359.75°
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 5.45 m/s
# Surface Wind Direction: 70.09°
# Surface Wind Heading: 250.09°
# Surface Pressure: 99631.87 hPa
# Surface Temperature: 293.39 K
# Surface Air Density: 118.300 kg/m³
# Surface Speed of Sound: 343.37 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6369.64 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
#
# Gravity Model Plots
# Atmospheric Model Plots

# %% [markdown]
# ## Motor

# %%
PRO75L645 = SolidMotor(
    thrust_source="assets/motors/Cesaroni_3419L645-P.eng",
    dry_mass=1.608,  # kilograms (launch mass=3.752, wet=2.144)
    dry_inertia=(0.01, 0.01, 0.001),  # kg*m^2
    nozzle_radius=2.38125 / 100,  # of nozzle exit in meters
    grain_number=3,  # Number of propellant grains
    grain_density=2400,  # 2563.3825,  # kg/m^3
    grain_outer_radius=2.794 / 100,  # meters
    grain_initial_inner_radius=0.01397,  # meters
    grain_initial_height=0.485648 / 3,  # meters
    grain_separation=5 / 1000,  # meters
    grains_center_of_mass_position=0.343,
    center_of_dry_mass_position=0.231,  # formula: lenngth of the aft part of the motor / (length of the aft part of the motor + length of the forward part of the motor)
    nozzle_position=0.1,  # relative to the combustion chamber
    burn_time=5.33,  # seconds
    throat_radius=1 * (2.38125 / 100),  # meters
    coordinate_system_orientation="nozzle_to_combustion_chamber",  # Orientation of the coordinate system -> EXTREMLY IMPORTANT
)
PRO75L645.all_info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.0238125 m
# Nozzle Throat Radius: 0.0238125 m
#
# Grain Details
# Number of Grains: 3
# Grain Spacing: 0.005 m
# Grain Density: 2400 kg/m3
# Grain Outer Radius: 0.02794 m
# Grain Inner Radius: 0.01397 m
# Grain Height: 0.16188266666666667 m
# Grain Volume: 0.000 m3
# Grain Mass: 0.715 kg
#
# Motor Details
# Total Burning Time: 5.33 s
# Total Propellant Mass: 2.144 kg
# Structural Mass Ratio: 0.429
# Average Propellant Exhaust Velocity: 1601.112 m/s
# Average Thrust: 644.008 N
# Maximum Thrust: 764.97 N at 2.043 s after ignition.
# Total Impulse: 3432.563 Ns

# %% [markdown]
# ##  Rocket

# %%
ROCKET_LENGTH = 1.81
ROCKET_RADIUS = 0.051

rocket = Rocket(
    radius=ROCKET_RADIUS,  # (r) body in meters 5.1cm = 0.051m
    mass=4.843,  # kg (dry)
    inertia=(1.2, 1.38, 0.3),  # Moments of inertia of the rocket in kg*m^2
    #power_off_drag="assets/aero/cd_power_off.csv",  # power-off drag curve csv
    #power_on_drag="assets/aero/cd_power_on.csv",  # power-on drag curve csv
    power_off_drag=0.5,
    power_on_drag=0.5,
    center_of_mass_without_motor=ROCKET_LENGTH - 0.917,
    coordinate_system_orientation="tail_to_nose",  # MUST be relative to the coordinate system defined in the motor
)

rail_buttons = rocket.set_rail_buttons(
    upper_button_position=0.5,  # relative to the rocket nozzle
    lower_button_position=0.3,  # relative to the rocket nozzle
    angular_position=45,  # degrees
)

tail = rocket.add_tail(
    top_radius=ROCKET_RADIUS,  # meters
    bottom_radius=0.041,  # meters
    length=0.07,  # meters
    position=0.07,  # relative to the rocket base
)

rocket.add_motor(PRO75L645, position=-0.09)

# %% [markdown]
# ##  Aero surfaces

# %%
nose_cone = rocket.add_nose(
    length=0.408,  # meters
    kind="lvhaack",  # cone profile
    position=ROCKET_LENGTH,  # relative to nose
    base_radius=ROCKET_RADIUS,  # meters
)

# %%
fin_set = rocket.add_trapezoidal_fins(
    n=4,
    root_chord=0.18,  # meters
    tip_chord=0.07,  # meters
    span=0.109,  # meters (aka height)
    position=ROCKET_LENGTH - 1.56,  # relative to the rocket base
    cant_angle=0,  # radians
    airfoil=("assets/aero/clv_alpha.csv", "degrees"),
    sweep_length=0.11,
)

# %% [markdown]
# ## Recovery

# %%
main_para = rocket.add_parachute(
    "Main",  # name
    cd_s=0.8,  # Drag coefficient of the parachute in m^2
    trigger=450,  # altitude (m) NOTE: Required by 3.1.2 - can't be higher than 450m AGL
    sampling_rate=105,
    lag=0.5,  # seconds
    noise=(0, 8.3, 0.5),
)

drogue_para = rocket.add_parachute(
    "Drogue",  # name
    cd_s=0.8,  # Drag coefficient of the parachute in m^2
    trigger="apogee",  # altitude in meters OR an event
    sampling_rate=105,
    lag=0.5,  # seconds
    noise=(0, 8.3, 0.5),
)

# %%
rocket.all_info()
# Out:
# Inertia Details
#
# Rocket Mass: 4.843 kg (without motor)
# Rocket Dry Mass: 6.451 kg (with unloaded motor)
# Rocket Loaded Mass: 8.595 kg
# Rocket Structural Mass Ratio: 0.751
# Rocket Inertia (with unloaded motor) 11: 1.893 kg*m2
# Rocket Inertia (with unloaded motor) 22: 2.073 kg*m2
# Rocket Inertia (with unloaded motor) 33: 0.301 kg*m2
# Rocket Inertia (with unloaded motor) 12: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 13: 0.000 kg*m2
# Rocket Inertia (with unloaded motor) 23: 0.000 kg*m2
#
# Geometrical Parameters
#
# Rocket Maximum Radius: 0.051 m
# Rocket Frontal Area: 0.008171 m2
#
# Rocket Distances
# Rocket Center of Dry Mass - Center of Mass without Motor: 0.187 m
# Rocket Center of Dry Mass - Nozzle Exit: 0.696 m
# Rocket Center of Dry Mass - Center of Propellant Mass: 0.453 m
# Rocket Center of Mass - Rocket Loaded Center of Mass: 0.113 m
#
#
# Aerodynamics Lift Coefficient Derivatives
#
# Tail Lift Coefficient Derivative: -0.707/rad
# Nose Cone Lift Coefficient Derivative: 2.000/rad
# Fins Lift Coefficient Derivative: 10.098/rad
# Fins Lift Coefficient Derivative: 10.098/rad
#
# Center of Pressure
#
# Tail Center of Pressure position: 0.036 m
# Nose Cone Center of Pressure position: 1.580 m
# Fins Center of Pressure position: 0.170 m
# Fins Center of Pressure position: 0.170 m
#
# Stability
#
# Center of Mass position (time=0): 0.593 m
# Center of Pressure position (time=0): 0.305 m
# Initial Static Margin (mach=0, time=0): 2.816 c
# Final Static Margin (mach=0, time=burn_out): 3.922 c
# Rocket Center of Mass (time=0) - Center of Pressure (mach=0): 0.287 m
#
#
# Parachute Details
#
# Parachute Main with a cd_s of 0.8000 m2
# Ejection signal trigger: 450 m (AGL)
# Ejection system refresh rate: 105.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 0.5 s
#
#
# Parachute Details
#
# Parachute Drogue with a cd_s of 0.8000 m2
# Ejection signal trigger: At Apogee
# Ejection system refresh rate: 105.000 Hz
# Time between ejection signal is triggered and the parachute is fully opened: 0.5 s
#
#
# Rocket Draw
# ----------------------------------------
# Mass Plots
# ----------------------------------------
# Aerodynamics Plots
# ----------------------------------------
# Drag Plots
# --------------------
# Stability Plots
# --------------------
# Thrust-to-Weight Plot
# ----------------------------------------

# %% [markdown]
# ## Flight
#
# Flight Trajectory
#
# - Yellow Line: Altitude (height over time)
# - Red Line: Vertical Velocity (speed in the vertical direction)
# - Purple Line: Acceleration (rate of change of velocity)
# - Teal/Cyan Line: Drag Force (aerodynamic drag acting on the rocket)

# %%
flight = Flight(
    rocket=rocket,
    environment=env,
    rail_length=12,  # meters
    inclination=84,  # launch rail (in degrees)
    heading=0,  # launch rail (in degrees)
)
flight.all_info()
# Out:
# WARNING: Trying to add flight phase starting *after* the one *proceeding* it. This may be caused by multiple parachutes being triggered simultaneously.
#
# Initial Conditions
#
# Initial time: 0.000 s
# Position - x: 0.00 m | y: 0.00 m | z: 164.93 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude (quaternions) - e0: 0.923 | e1: -0.048 | e2: 0.020 | e3: 0.382
# Euler Angles - Spin φ : 45.00° | Nutation θ: -6.00° | Precession ψ: 0.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s | ω3: 0.00 rad/s
# Initial Stability Margin: 2.816 c
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: -1.84 m/s
# Lateral Surface Wind Speed: 5.13 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 12 m
# Launch Rail Inclination: 84.00°
# Launch Rail Heading: 0.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 0.656 s
# Rail Departure Velocity: 34.496 m/s
# Rail Departure Stability Margin: 2.922 c
# Rail Departure Angle of Attack: 9.152°
# Rail Departure Thrust-Weight Ratio: 8.507
# Rail Departure Reynolds Number: 2.336e+07
#
#
# Burn out State
#
# Burn out time: 5.330 s
# Altitude at burn out: 396.768 m (ASL) | 231.842 m (AGL)
# Rocket speed at burn out: 31.578 m/s
# Freestream velocity at burn out: 32.857 m/s
# Mach Number at burn out: 0.096
# Kinetic energy at burn out: 3.216e+03 J
#
#
# Apogee State
#
# Apogee Time: 7.241 s
# Apogee Altitude: 417.536 m (ASL) | 252.610 m (AGL)
# Apogee Freestream Speed: 2.281 m/s
# Apogee X position: -4.258 m
# Apogee Y position: 38.576 m
# Apogee latitude: 39.2073790°
# Apogee longitude: -8.0581154°
#
#
# Parachute Events
#
# Parachute: Main
# 	Ejection time: 7.248 s
# 	Inflation time: 7.748 s
# 	Freestream speed at inflation: 2.698 m/s
# 	Altitude at inflation: 416.836 m (ASL) | 251.910 m (AGL)
# Parachute: Drogue
# 	Ejection time: 7.257 s
# 	Inflation time: 7.757 s
# 	Freestream speed at inflation: 2.597 m/s
# 	Altitude at inflation: 416.815 m (ASL) | 251.889 m (AGL)
#
#
# Impact Conditions
#
# Time of impact: 224.452 s
# X impact: -1438.685 m
# Y impact: -440.241 m
# Altitude impact: 164.926 m (ASL) | 0.000 m (AGL)
# Latitude: 39.2030708°
# Longitude: -8.0747662°
# Vertical velocity at impact: -1.156 m/s
# Number of parachutes triggered until impact: 2
#
#
# Stability Margin
#
# Initial Stability Margin: 2.816 c at 0.00 s
# Out of Rail Stability Margin: 2.922 c at 0.66 s
# Maximum Stability Margin: 3.924 c at 5.33 s
# Minimum Stability Margin: 2.816 c at 0.00 s
#
#
# Maximum Values
#
# Maximum Speed: 52.191 m/s at 2.28 s
# Maximum Mach Number: 0.155 Mach at 2.28 s
# Maximum Reynolds Number: 3.511e+07 at 2.28 s
# Maximum Dynamic Pressure: 1.652e+05 Pa at 2.28 s
# Maximum Acceleration During Motor Burn: 203.683 m/s² at 0.66 s
# Maximum Gs During Motor Burn: 20.770 g at 0.66 s
# Maximum Acceleration After Motor Burn: 48.950 m/s² at 5.33 s
# Maximum Gs After Motor Burn: 4.992 Gs at 5.33 s
# Maximum Stability Margin: 3.924 c at 5.33 s
# Maximum Upper Rail Button Normal Force: 6.245 N
# Maximum Upper Rail Button Shear Force: 17.945 N
# Maximum Lower Rail Button Normal Force: 678.599 N
# Maximum Lower Rail Button Shear Force: 1912.036 N
#
#
#
# Numerical Integration Settings
#
# Maximum Allowed Flight Time: 600.00 s
# Maximum Allowed Time Step: inf s
# Minimum Allowed Time Step: 0.00e+00 s
# Relative Error Tolerance: 1e-06
# Absolute Error Tolerance: [0.001, 0.001, 0.001, 0.001, 0.001, 0.001, 1e-06, 1e-06, 1e-06, 1e-06, 0.001, 0.001, 0.001]
# Allow Event Overshoot: True
# Terminate Simulation on Apogee: False
# Number of Time Steps Used: 372
# Number of Derivative Functions Evaluation: 306
# Average Function Evaluations per Time Step: 0.823
#
#
#
# Trajectory 3d Plot
# Trajectory Kinematic Plots
# Angular Position Plots
# Path, Attitude and Lateral Attitude Angle plots
# Trajectory Angular Velocity and Acceleration Plots
# Aerodynamic Forces Plots
# Rail Buttons Bending Moments Plots
#
# Rail button height not defined. Skipping bending moment plots.
#
#
# Rail Buttons Forces Plots
# Trajectory Energy Plots
# Trajectory Fluid Mechanics Plots
# Trajectory Stability and Control Plots
# Rocket and Parachute Pressure Plots
# Parachute:  Main
# Parachute:  Drogue

# %% [markdown]
# ## Export

# %%
flight.export_kml("assets/results/Technical.kml")
# Out:
# File  assets/results/Technical.kml  saved with success!
